# %%
print("Hello Abhishek")
# Out:
# Hello Abhishek

# %%
import pandas as pd

df = pd.read_excel(
    r"C:\Users\mrrus\data-bootcamp\Assignment-1_Data.xlsx",
    engine="openpyxl"
)

print(df.head())
#print("Shape:", df.shape)
# Out:
#    BillNo                             Itemname  Quantity                Date  \
# 0  536365   WHITE HANGING HEART T-LIGHT HOLDER         6 2010-12-01 08:26:00
# 1  536365                  WHITE METAL LANTERN         6 2010-12-01 08:26:00
# 2  536365       CREAM CUPID HEARTS COAT HANGER         8 2010-12-01 08:26:00
# 3  536365  KNITTED UNION FLAG HOT WATER BOTTLE         6 2010-12-01 08:26:00
# 4  536365       RED WOOLLY HOTTIE WHITE HEART.         6 2010-12-01 08:26:00
#
#    Price  CustomerID         Country
# 0   2.55     17850.0  United Kingdom
# 1   3.39     17850.0  United Kingdom
# 2   2.75     17850.0  United Kingdom
# 3   3.39     17850.0  United Kingdom
# 4   3.39     17850.0  United Kingdom

# %%
print("Shape:", df.shape)
# Out:
# Shape: (522064, 7)

# %%
print(df.dtypes)
# Out:
# BillNo                object
# Itemname                 str
# Quantity               int64
# Date          datetime64[us]
# Price                float64
# CustomerID           float64
# Country                  str
# dtype: object

# %%
print(df.describe(include="all"))
# Out:
#           BillNo                            Itemname       Quantity  \
# count   522064.0                              520609  522064.000000
# unique   21663.0                                4185            NaN
# top     573585.0  WHITE HANGING HEART T-LIGHT HOLDER            NaN
# freq      1114.0                                2269            NaN
# mean         NaN                                 NaN      10.090435
# min          NaN                                 NaN   -9600.000000
# 25%          NaN                                 NaN       1.000000
# 50%          NaN                                 NaN       3.000000
# 75%          NaN                                 NaN      10.000000
# max          NaN                                 NaN   80995.000000
# std          NaN                                 NaN     161.110525
#
#                               Date          Price     CustomerID  \
# count                       522064  522064.000000  388023.000000
# unique                         NaN            NaN            NaN
# top                            NaN            NaN            NaN
# freq                           NaN            NaN            NaN
# mean    2011-07-04 12:51:20.777107       3.826801   15316.931710
# min            2010-12-01 08:26:00  -11062.060000   12346.000000
# 25%            2011-03-28 10:15:00       1.250000   13950.000000
# 50%            2011-07-20 08:59:00       2.080000   15265.000000
# 75%            2011-10-19 14:12:00       4.130000   16837.000000
# max            2011-12-09 12:50:00   13541.330000   18287.000000
# std                            NaN      41.900599    1721.846964
#
#                Country
# count           522064
# unique              30
# top     United Kingdom
# freq            487622
# mean               NaN
# min                NaN
# 25%                NaN
# 50%                NaN
# 75%                NaN
# max                NaN
# std                NaN

# %%
print(df.isnull().sum())
# Out:
# BillNo             0
# Itemname        1455
# Quantity           0
# Date               0
# Price              0
# CustomerID    134041
# Country            0
# dtype: int64

# %%
import matplotlib.pyplot as plt

plt.hist(df["Price"], bins=30)

plt.title("Price Distribution")
plt.xlabel("Price")
plt.ylabel("Frequency")

plt.show()

# %%
plt.hist(df["Quantity"], bins=30)

plt.title("Quantity Distribution")
plt.xlabel("Quantity")
plt.ylabel("Frequency")

plt.show()

# %%
print(df["Country"].value_counts().head(10))
# Out:
# Country
# United Kingdom    487622
# Germany             9042
# France              8408
# Spain               2485
# Netherlands         2363
# Belgium             2031
# Switzerland         1967
# Portugal            1501
# Australia           1185
# Norway              1072
# Name: count, dtype: int64

# %%
print(df.groupby("Country")["Price"].mean().sort_values(ascending=False).head(10))
# Out:
# Country
# Singapore    58.333288
# Hong Kong    23.474437
# Portugal      5.843251
# Lebanon       5.387556
# Norway        5.282155
# Malta         4.867768
# Italy         4.717955
# Bahrain       4.597778
# Greece        4.574414
# Brazil        4.456250
# Name: Price, dtype: float64
